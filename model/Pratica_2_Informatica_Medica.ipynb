# %% [markdown]
# <head><p><img alt="udeA logo" height="150px" src="https://github.com/freddyduitama/images/blob/master/logo.png?raw=true" align="left" hspace="50px" vspace="0px" style="width:107px;height:152px;"></p>
# <h1><font color='black'> <center>
#        Informática médica </center></font></h1>
# <p3><center><b><font color='black' face="Lucida Calligraphy,Comic Sans MS,Lucida Console" size="5">Universidad de Antioquia</font></b> </center></p3>
# </font>
# <h2><font color='black'> <center>
# Práctica 3 - Análisis </center></font></h2>
# <h3><font color='black'> <center>
# Citlali Garcia Banda - Danna Isabella Garcia Saenz - Silvania Sofia Ramos Paternina </center></font></h3>
# <font  face="Courier New" size="3">
# <p1><center> </center></p1></head>

# %% [markdown]
# ##**CARGA DE DATOS E IMPORTACIONES**

# %%
# Instalar seaborn
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 330.3 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 469.7 kB/s eta 0:00:01
#    --------------------- ---------------- 163.8/294.9 kB 984.6 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#    ---------------------------------------- 0.0/251.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.3 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/251.3 kB 325.1 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/251.3 kB 798.9 kB/s eta 0:00:01
#    ---------------------------------------  245.8/251.3 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 251.3/251.3 kB 1.2 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %%
df = pd.read_excel('C:\\Users\\sense\\Infomedica\\BD_URGENCIAS_BIO.xlsx')
#df.head()

# %%
list_ = []
for i in df.columns:
    list_.append(i.replace(' ','_').replace('\n',''))
df.columns = list_
#df.head()

# %% [markdown]
# ##**ANALISIS GENERAL DE LAS VARIBALES**

# %% [markdown]
# **Variables**

# %%
df.columns
# Out:
# Index(['COD', 'DESCRIPCION', 'Año', 'Mes', 'Paciente_Tipo_Identificacion',
#        'Nro_Atencion', 'Servicio_Admite', 'Servicio_Anterior',
#        'Servicio_Egreso', 'Tipo_Egreso_(INTERNACION)',
#        'Paciente_Entidad_Responsable_Pago', 'Paciente_Modalidad_Contrato',
#        'Paciente_Regimen_Afiliacion', 'Urg_Fecha_(Camara)',
#        'Urg_Fecha_Ingreso', 'Urg_Fecha_Triaje', 'Urg_Fecha_Consulta_F3',
#        'Dias_(Camara_-_F3)', 'Horas_(Camara_-_F3)', 'Minutos_(Camara_-_F3)',
#        'Urg_Demora1_Consulta_(Minutos)', 'Dias_(Camara_-_Triaje)',
#        'Horas_(Camara_-_Triaje)', 'Urg_Demora_Triaje_(Minutos)',
#        'Dias_(Triaje_-_F3)', 'Horas_(Triaje_-_F3)', 'Minutos_(Triaje_-_F3)',
#        'Urg_Demora2_Consulta_(Minutos)', 'Profesional_Especialidad',
#        'Dx_Principal_Tipo_', 'Dx_Principal_Cod', 'Dx_Principal',
#        'Dx_Principal_Capitulo_Cod', 'Dx_Principal_Capitulo',
#        'Dx_Principal_Cod.1', 'Dx_Principal.1', 'Dx_Relacionado1_Cod',
#        'Dx_Relacionado1', 'Dx_Relacionado2_Cod_', 'Dx_Relacionado2',
#        'Dx_Relacionado3_Cod', 'Dx_Relacionado3', 'Paciente_Edad', 'Unidad',
#        'Grupo_Edad', 'Paciente_Sexo', 'Clasificacion_1_Triaje_Enfermeria_',
#        'Clasificacion_Urg_(Nivel)Enfermeria_', 'Ubicacion__Urgencias',
#        'Causa_Externa__(Riesgo)', 'Modalidad_Atencion', 'Ubicación_Triaje',
#        'Profesional_Identificacion', 'Tiempo_Duracion_Diligenciamiento_F3',
#        'Hora_Diligenciamiento_F3', 'Dias', 'Horas', 'Minutos',
#        'Triaje_Re-clasificado', 'Tiempo_Egreso_Urgencias',
#        'Tiempo_Traslado_Hospitalizacion', 'Tiempo_Cirugia',
#        'Tiempo_Resolutividad_Hosp', 'Tiempo_Resolutividad_Cx',
#        'Tiempo_Resolutividad_Alta', 'Tiempo_Resolutividad_Total',
#        'Urgencia_Xpress_F3', 'Grupo_Poblacional', 'Pertenencia_Etnica',
#        'ALTO_COSTO'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39745 entries, 0 to 39744
# Data columns (total 70 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COD                                   39745 non-null  int64
#  1   DESCRIPCION                           39745 non-null  object
#  2   Año                                   39745 non-null  int64
#  3   Mes                                   39745 non-null  object
#  4   Paciente_Tipo_Identificacion          39745 non-null  object
#  5   Nro_Atencion                          39745 non-null  int64
#  6   Servicio_Admite                       39745 non-null  object
#  7   Servicio_Anterior                     32226 non-null  object
#  8   Servicio_Egreso                       39745 non-null  object
#  9   Tipo_Egreso_(INTERNACION)             39745 non-null  object
#  10  Paciente_Entidad_Responsable_Pago     39745 non-null  int64
#  11  Paciente_Modalidad_Contrato           39745 non-null  object
#  12  Paciente_Regimen_Afiliacion           39739 non-null  object
#  13  Urg_Fecha_(Camara)                    39745 non-null  object
#  14  Urg_Fecha_Ingreso                     39745 non-null  object
#  15  Urg_Fecha_Triaje                      37092 non-null  object
#  16  Urg_Fecha_Consulta_F3                 39745 non-null  object
#  17  Dias_(Camara_-_F3)                    39744 non-null  float64
#  18  Horas_(Camara_-_F3)                   39744 non-null  float64
#  19  Minutos_(Camara_-_F3)                 39745 non-null  float64
#  20  Urg_Demora1_Consulta_(Minutos)        39745 non-null  float64
#  21  Dias_(Camara_-_Triaje)                39745 non-null  int64
#  22  Horas_(Camara_-_Triaje)               39745 non-null  float64
#  23  Urg_Demora_Triaje_(Minutos)           39745 non-null  float64
#  24  Dias_(Triaje_-_F3)                    39745 non-null  int64
#  25  Horas_(Triaje_-_F3)                   39745 non-null  float64
#  26  Minutos_(Triaje_-_F3)                 39745 non-null  float64
#  27  Urg_Demora2_Consulta_(Minutos)        39745 non-null  float64
#  28  Profesional_Especialidad              39745 non-null  object
#  29  Dx_Principal_Tipo_                    39743 non-null  object
#  30  Dx_Principal_Cod                      39745 non-null  object
#  31  Dx_Principal                          39745 non-null  object
#  32  Dx_Principal_Capitulo_Cod             39723 non-null  object
#  33  Dx_Principal_Capitulo                 39723 non-null  object
#  34  Dx_Principal_Cod.1                    39723 non-null  object
#  35  Dx_Principal.1                        39723 non-null  object
#  36  Dx_Relacionado1_Cod                   5322 non-null   object
#  37  Dx_Relacionado1                       5322 non-null   object
#  38  Dx_Relacionado2_Cod_                  1456 non-null   object
#  39  Dx_Relacionado2                       1456 non-null   object
#  40  Dx_Relacionado3_Cod                   945 non-null    object
#  41  Dx_Relacionado3                       945 non-null    object
#  42  Paciente_Edad                         39745 non-null  int64
#  43  Unidad                                39745 non-null  object
#  44  Grupo_Edad                            39739 non-null  object
#  45  Paciente_Sexo                         39745 non-null  object
#  46  Clasificacion_1_Triaje_Enfermeria_    39737 non-null  object
#  47  Clasificacion_Urg_(Nivel)Enfermeria_  39745 non-null  object
#  48  Ubicacion__Urgencias                  39737 non-null  object
#  49  Causa_Externa__(Riesgo)               39745 non-null  object
#  50  Modalidad_Atencion                    39737 non-null  object
#  51  Ubicación_Triaje                      39745 non-null  object
#  52  Profesional_Identificacion            39737 non-null  float64
#  53  Tiempo_Duracion_Diligenciamiento_F3   30180 non-null  object
#  54  Hora_Diligenciamiento_F3              39744 non-null  float64
#  55  Dias                                  39744 non-null  float64
#  56  Horas                                 39744 non-null  float64
#  57  Minutos                               39744 non-null  float64
#  58  Triaje_Re-clasificado                 39745 non-null  object
#  59  Tiempo_Egreso_Urgencias               28820 non-null  float64
#  60  Tiempo_Traslado_Hospitalizacion       21097 non-null  float64
#  61  Tiempo_Cirugia                        18100 non-null  float64
#  62  Tiempo_Resolutividad_Hosp             22509 non-null  float64
#  63  Tiempo_Resolutividad_Cx               17261 non-null  float64
#  64  Tiempo_Resolutividad_Alta             25201 non-null  float64
#  65  Tiempo_Resolutividad_Total            39745 non-null  int64
#  66  Urgencia_Xpress_F3                    39745 non-null  bool
#  67  Grupo_Poblacional                     39742 non-null  object
#  68  Pertenencia_Etnica                    39736 non-null  object
#  69  ALTO_COSTO                            39725 non-null  object
# dtypes: bool(1), float64(20), int64(8), object(41)
# memory usage: 21.0+ MB

# %%
df.describe()
# Out:
#            COD      Año  Nro_Atencion  Paciente_Entidad_Responsable_Pago  \
# count  39745.0  39745.0  3.974500e+04                       39745.000000
# mean    1102.0   2023.0  1.345857e+11                          38.846396
# std        0.0      0.0  7.955160e+10                          21.252590
# min     1102.0   2023.0  1.234032e+07                           1.000000
# 25%     1102.0   2023.0  6.537377e+10                          18.000000
# 50%     1102.0   2023.0  1.329287e+11                          48.000000
# 75%     1102.0   2023.0  2.029542e+11                          48.000000
# max     1102.0   2023.0  2.755966e+11                          74.000000
#
#        Dias_(Camara_-_F3)  Horas_(Camara_-_F3)  Minutos_(Camara_-_F3)  \
# count             39744.0         39744.000000           39745.000000
# mean                  0.0             0.042736              61.537700
# std                   0.0             0.058331              83.997075
# min                   0.0             0.000000               0.000000
# 25%                   0.0             0.000000               0.000000
# 50%                   0.0             0.032068              46.166667
# 75%                   0.0             0.054758              78.850000
# max                   0.0             0.748102            1077.266667
#
#        Urg_Demora1_Consulta_(Minutos)  Dias_(Camara_-_Triaje)  \
# count                    39745.000000                 39745.0
# mean                        43.183693                     0.0
# std                         76.696936                     0.0
# min                          0.000000                     0.0
# 25%                          0.000000                     0.0
# 50%                         19.133333                     0.0
# 75%                         48.850000                     0.0
# max                       1047.266667                     0.0
#
#        Horas_(Camara_-_Triaje)  ...          Dias         Horas  \
# count             39745.000000  ...  39744.000000  39744.000000
# mean                  0.005150  ...      0.084667      2.180379
# std                   0.006997  ...      1.148883     27.065652
# min                   0.000000  ...      0.000000    -18.000000
# 25%                   0.000000  ...      0.000000      0.000000
# 50%                   0.002847  ...      0.000000      1.000000
# 75%                   0.007581  ...      0.000000      2.000000
# max                   0.154021  ...    148.000000   3556.000000
#
#              Minutos  Tiempo_Egreso_Urgencias  \
# count   39744.000000             28820.000000
# mean      114.700081              1032.735427
# std      1547.257898              1750.003457
# min     -1038.000000            -31963.000000
# 25%        23.000000               153.000000
# 50%        51.000000               438.000000
# 75%       100.000000              1264.000000
# max    213364.000000             45725.000000
#
#        Tiempo_Traslado_Hospitalizacion  Tiempo_Cirugia  \
# count                     21097.000000    18100.000000
# mean                        709.835664      989.108950
# std                        2426.267218     2779.918034
# min                        -124.000000        0.000000
# 25%                           0.000000        0.000000
# 50%                           6.000000        0.000000
# 75%                          45.000000      423.000000
# max                       38413.000000   143089.000000
#
#        Tiempo_Resolutividad_Hosp  Tiempo_Resolutividad_Cx  \
# count               22509.000000             17261.000000
# mean                  342.348483               596.990267
# std                   853.176379              2205.600704
# min                 -1362.000000             -5496.000000
# 25%                     0.000000                 0.000000
# 50%                   142.000000                 0.000000
# 75%                   405.000000                10.000000
# max                 32144.000000             38104.000000
#
#        Tiempo_Resolutividad_Alta  Tiempo_Resolutividad_Total
# count               25201.000000                39745.000000
# mean                 1067.947066                 1130.303309
# std                  3179.767137                 2933.000766
# min                     0.000000                -5496.000000
# 25%                     0.000000                  114.000000
# 50%                   176.000000                  304.000000
# 75%                   438.000000                  674.000000
# max                 43222.000000                43222.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# **El DataFrame tiene un total de 70 columnas, enumeradas del 0 al 69, y 39745 filas**

# %%
# Frecuencia de valores para variables categóricas
for columna in df.select_dtypes(include='object').columns:
    print(df[columna].value_counts())
# Out:
# DESCRIPCION
# URGENCIAS ADULTO         31903
# URGENCIAS PEDIATRICAS     7842
# Name: count, dtype: int64
# Mes
# ABRIL         4022
# MARZO         4021
# MAYO          3850
# AGOSTO        3624
# JUNIO         3564
# JULIO         3542
# FEBRERO       3027
# SEPTIEMBRE    2872
# DICIEMBRE     2855
# OCTUBRE       2811
# ENERO         2810
# NOVIEMBRE     2747
# Name: count, dtype: int64
# Paciente_Tipo_Identificacion
# CC    31057
# RC     5079
# TI     2930
# PT      425
# AS      115
# CE       36
# PA       30
# CN       25
# MS       24
# PE       18
# SC        6
# Name: count, dtype: int64
# Servicio_Admite
# URGENCIAS GENERALES SÓTANO    18977
# NO APLICA                     16320
# HOSPITALIZACIÓN                2727
# URGENCIAS PEDIÁTRICAS          1559
# URGENCIAS GENERALES PISO 1      132
# CIRUGÍA                          21
# AMBULATORIA PROGRAMADA            4
# ATENCIÓN PRIORITARIA              3
# AMBULATORIA PERSONAL              1
# TELETRIAJE                        1
# Name: count, dtype: int64
# Servicio_Anterior
# NO APLICA                                           16320
# PISO 6 UCE                                           1597
# SALA DE TRANSICIÓN                                   1553
# CAMILLAS SALA 4  URGENCIAS                           1476
# CAMILLAS SAI ADULTOS                                  924
# CAMILLAS SAI PEDIATRIA                                829
# CAMILLAS SALA 2  URGENCIAS                            813
# CIRUGIA                                               794
# CAMILLAS SALA 3  URGENCIAS                            756
# CAMILLAS SALA 6  URGENCIAS                            727
# CAMILLAS SALA 1  URGENCIAS                            691
# CAMILLAS SALA 5 URGENCIAS                             647
# CAMILLAS SALA 7  URGENCIAS                            628
# ERA PEDIATRÍA                                         453
# PISO 7 MEDICINA INTERNA SUR                           348
# PISO 2 OCCIDENTE                                      304
# PISO 4 OCCIDENTE                                      223
# PISO 7 UCI NEUROCIRUGÍA                               194
# PISO_10 MEDICINA INTERNA                              189
# PISO 5 MEDICINA INTERNA SUR                           184
# PISO 4 MEDICINA INTERNA SUR                           179
# PISO 7 UCI CARDIOVASCULAR                             162
# PISO 5 MEDICINA INTERNA NORTE                         160
# PISO 3 OCCIDENTE                                      139
# PISO 4 ORIENTE                                        135
# PISO 4 MEDICINA INTERNA NORTE                         134
# PISO 7 UCI MEDICOQUIRÚRGICA                           131
# PISO 4 UCI ORIENTE                                    130
# PISO 3 PEDIATRÍA                                      112
# PISO 7 MEDICINA INTERNA NORTE                         110
# PISO 3 ORIENTE                                        104
# PISO 8 MEDICINA INTERNA NORTE                          90
# PISO 6 MEDICINA INTERNA SUR                            88
# PISO 6 MEDICINA INTERNA NORTE                          86
# PISO 2 ORIENTE                                         85
# PISO 5 UCI                                             84
# PISO 3                                                 75
# PISO 8 MEDICINA INTERNA SUR                            73
# SALA APLI                                              73
# PISO 9 MEDICINA INTERNA NORTE                          71
# PISO 9 MEDICINA INTERNA SUR                            62
# EXPANSIÓN PEDIATRÍA                                    62
# CAMILLAS SALA 8 URGENCIAS                              59
# REANIMACIÓN ADULTOS                                    56
# SALA AISLADOS PEDIATRÍA                                51
# CAMILLAS SALA REMITIDOS                                21
# SALA DE REHIDRATACIÓN ORAL                             14
# BIENESTAR CIRUGÍA                                       9
# URGENCIAS EXPANSIÓN                                     9
# CECLAB LABORATORIO DE CORRELACION ELECTROCLINICA        7
# SERVICIO PRETRASPLANTES VIRTUALES                       3
# URGENCIAS ONCOLOGÍA                                     1
# PROCEDIMIENTOS SANT CI                                  1
# Name: count, dtype: int64
# Servicio_Egreso
# NO APLICA                        16320
# PISO 4 OCCIDENTE                  1305
# PISO 7 MEDICINA INTERNA SUR       1207
# PISO 2 OCCIDENTE                  1195
# PISO 5 MEDICINA INTERNA SUR       1130
# PISO 4 MEDICINA INTERNA SUR       1129
# PISO 5 MEDICINA INTERNA NORTE     1024
# PISO 3 PEDIATRÍA                  1021
# PISO 3 MEDICINA INTERNA            951
# PISO 3 OCCIDENTE                   924
# SALA DE TRANSICIÓN                 821
# PISO 4 MEDICINA INTERNA NORTE      749
# PISO_10 MEDICINA INTERNA           708
# PISO 8 MEDICINA INTERNA SUR        682
# PISO 7 MEDICINA INTERNA NORTE      671
# CAMILLAS SALA 2  URGENCIAS         668
# CAMILLAS SALA 6  URGENCIAS         618
# CAMILLAS SALA 3  URGENCIAS         601
# CAMILLAS SALA 4  URGENCIAS         599
# PISO 6 MEDICINA INTERNA NORTE      592
# CAMILLAS SALA 5 URGENCIAS          584
# PISO 6 MEDICINA INTERNA SUR        574
# CAMILLAS SALA 1  URGENCIAS         572
# PISO 8 MEDICINA INTERNA NORTE      568
# CAMILLAS SALA 7  URGENCIAS         566
# PISO 2 ORIENTE                     560
# PISO 3 ORIENTE                     473
# CAMILLAS SAI PEDIATRIA             467
# PISO 4 ORIENTE                     392
# CAMILLAS SAI ADULTOS               340
# PISO 9 MEDICINA INTERNA SUR        306
# ERA PEDIATRÍA                      258
# PISO 9 MEDICINA INTERNA NORTE      226
# PISO 6 UCE                         217
# PISO 7 UCI NEUROCIRUGÍA            144
# PISO 4 UCI ORIENTE                 111
# PISO 7 UCI CARDIOVASCULAR           94
# PISO 5 UCI                          93
# PISO 7 UCI MEDICOQUIRÚRGICA         84
# SALA AISLADOS PEDIATRÍA             69
# REANIMACIÓN ADULTOS                 36
# CAMILLAS SALA 8 URGENCIAS           35
# EXPANSIÓN PEDIATRÍA                 33
# SALA APLI                           17
# CAMILLAS SALA REMITIDOS              9
# SALA DE REHIDRATACIÓN ORAL           2
# Name: count, dtype: int64
# Tipo_Egreso_(INTERNACION)
# ALTA MÉDICA                    20348
# NO APLICA                      16320
# FALLECE                         1489
# REMISIÓN A OTRA INSTITUCIÓN     1306
# ALTA VOLUNTARIA                  251
# FUGA                              31
# Name: count, dtype: int64
# Paciente_Modalidad_Contrato
# EVENTO    33740
# PGP        5974
# CAPITA       31
# Name: count, dtype: int64
# Paciente_Regimen_Afiliacion
# CONTRIBUTIVO    16424
# SUBSIDIADO      13006
# ESPECIAL         6987
# NO ASEGURADO     3322
# Name: count, dtype: int64
# Urg_Fecha_(Camara)
# 15/06/2023 5:54:12            2
# 2023-03-23 14:27:15.507000    2
# 12/06/2023 20:39:26           2
# 12/05/2023 19:40:21           2
# 12/07/2023 17:09:43           2
#                              ..
# 27/04/2023 12:56:37           1
# 18/04/2023 7:39:54            1
# 24/04/2023 17:46:30           1
# 29/04/2023 16:44:02           1
# 30/12/2023 12:47:35           1
# Name: count, Length: 39724, dtype: int64
# Urg_Fecha_Ingreso
# 30/05/2023 12:54:43    2
# 25/05/2023 9:52:49     2
# 17/07/2023 15:24:09    2
# 31/07/2023 13:02:57    2
# 10/04/2023 18:11:59    2
#                       ..
# 21/04/2023 2:16:16     1
# 20/04/2023 13:41:53    1
# 27/04/2023 13:06:34    1
# 18/04/2023 7:46:42     1
# 30/12/2023 13:01:25    1
# Name: count, Length: 39723, dtype: int64
# Urg_Fecha_Triaje
# 11/05/2023 21:14:43    2
# 25/08/2023 17:32:57    2
# 25/04/2023 10:02:43    2
# 12/07/2023 13:20:18    2
# 07/06/2023 10:15:23    2
#                       ..
# 22/04/2023 13:22:50    1
# 25/04/2023 15:02:04    1
# 25/04/2023 13:30:18    1
# 25/04/2023 1:52:27     1
# 30/12/2023 12:54:21    1
# Name: count, Length: 37082, dtype: int64
# Urg_Fecha_Consulta_F3
# 19/08/2023 11:31:24    2
# 29/04/2023 15:24:54    2
# 24/08/2023 13:20:27    2
# 10/08/2023 17:56:41    2
# 20/04/2023 0:18:09     2
#                       ..
# 19/04/2023 18:42:39    1
# 21/04/2023 3:06:22     1
# 20/04/2023 14:04:49    1
# 27/04/2023 13:06:34    1
# 30/12/2023 14:17:51    1
# Name: count, Length: 39725, dtype: int64
# Profesional_Especialidad
# MEDICINA GENERAL                               34129
# PEDIATRIA                                       2948
# URGENTOLOGIA                                    2378
# INTENSIVISTA                                     146
# PEDIATRÍA                                         37
# ESTUDIANTE                                        33
# ENSAYO CLINICO                                    29
# PSIQUIATRIA                                        8
# MEDICINA INTERNA                                   8
# CIRUGIA GENERAL                                    7
# ANESTESIOLOGIA                                     5
# ORTOPEDIA                                          5
# GERIATRIA                                          4
# CIRUGIA TORAX                                      2
# CIRUGIA DE CABEZA Y CUELLO                         2
# CIRUGIA PLASTICA- MAXILOFACIAL Y DE LA MANO        1
# NEUROLOGIA                                         1
# OTORRINOLARINGOLOGIA                               1
# ENFERMERA                                          1
# Name: count, dtype: int64
# Dx_Principal_Tipo_
# NUEVO       29712
# REPETIDO    10031
# Name: count, dtype: int64
# Dx_Principal_Cod
# R104    2044
# R509     927
# N390     914
# R51X     729
# J441     607
#         ...
# S365       1
# Z761       1
# I610       1
# M171       1
# D337       1
# Name: count, Length: 2519, dtype: int64
# Dx_Principal
# OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS                                   2044
# INFECCION DE VIAS URINARIAS  SITIO NO ESPECIFICADO                                  687
# FIEBRE  NO ESPECIFICADA                                                             666
# ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EXACERBACION AGUDA  NO ESPECIFICADA     607
# DOLOR EN EL PECHO  NO ESPECIFICADO                                                  589
#                                                                                    ...
# OTRAS DIABETES MELLITUS ESPECIFICADAS  CON COMPLICACIONES NO ESPECIFICADAS            1
# TUMOR MALIGNO DE GLANDULA ENDOCRINA NO ESPECIFICADA                                   1
# TUBERCULOSIS DE HUESOS Y ARTICULACIONES                                               1
# QUISTE DE LA GLANDULA DE BARTHOLIN                                                    1
# TUMOR BENIGNO DE OTRAS PARTES ESPECIFICADAS DEL SISTEMA NERVIOSO CENTRAL              1
# Name: count, Length: 2818, dtype: int64
# Dx_Principal_Capitulo_Cod
# R10    2830
# R07    1081
# A09     948
# R50     938
# N39     916
#        ...
# Q15       1
# Q81       1
# G02       1
# D56       1
# Y51       1
# Name: count, Length: 1018, dtype: int64
# Dx_Principal_Capitulo
# DOLOR ABDOMINAL Y PELVICO                                                                2830
# DOLOR DE GARGANTA Y EN EL PECHO                                                          1081
# OTRAS GASTROENTERITIS Y COLITIS DE ORIGEN INFECCIOSO Y NO ESPECIFICADO                    948
# FIEBRE DE OTRO ORIGEN Y DE ORIGEN DESCONOCIDO                                             938
# OTROS TRASTORNOS DEL SISTEMA URINARIO                                                     916
#                                                                                          ...
# OTRAS MALFORMACIONES CONGENITAS DEL OJO                                                     1
# EPIDERMOLISIS BULLOSA                                                                       1
# MENINGITIS EN OTRAS ENFERMEDADES INFECCIOSAS Y PARASITARIAS CLASIFICADA EN OTRA PARTE       1
# TALASEMIA                                                                                   1
# EFECTOS ADVERSOS DE DROGAS QUE AFECTAN PRIMARIAMENTE EL SISTEMA NERVIOSO AUTONOMO           1
# Name: count, Length: 1019, dtype: int64
# Dx_Principal_Cod.1
# S00-T98    10256
# R00-R99     9417
# J00-J99     3151
# I00-I99     2829
# N00-N99     2356
# K00-K93     2151
# A00-B99     1600
# M00-M99     1450
# C00-D48     1234
# F00-F99     1155
# G00-G99      778
# L00-L99      769
# E00-E90      616
# H60-H95      516
# Z00-Z99      463
# H00-H59      356
# D50-D89      337
# V01-Y98      212
# Q00-Q99       50
# P00-P96       16
# U00-U99        9
# O00-O99        2
# Name: count, dtype: int64
# Dx_Principal.1
# TRAUMATISMOS, ENVENENAMIENTO Y ALGUNAS OTRAS CONSECUENCIAS DE CAUSAS EXTERNAS                                                 10002
# SINTOMAS, SIGNOS Y HALLAZGOS ANORMALES CLINICOS Y DE LABORATORIO, NO CLASIFICADOS EN OTRA PARTE                                9603
# ENFERMEDADES DEL SISTEMA RESPIRATORIO                                                                                          3029
# ENFERMEDADES DEL SISTEMA CIRCULATORIO                                                                                          2950
# ENFERMEDADES DEL SISTEMA GENITOURINARIO                                                                                        2355
# ENFERMEDADES DEL SISTEMA DIGESTIVO                                                                                             2151
# CIERTAS ENFERMEDADES INFECCIOSAS Y PARASITARIAS                                                                                1602
# ENFERMEDADES DEL SISTEMA OSTEOMUSCULAR Y DEL TEJIDO CONJUNTIVO                                                                 1439
# TUMORES [NEOPLASIAS]                                                                                                           1244
# TRASTORNOS MENTALES Y DEL COMPORTAMIENTO                                                                                       1157
# ENFERMEDADES DE LA PIEL Y DEL TEJIDO SUBCUTANEO                                                                                 781
# ENFERMEDADES DEL SISTEMA NERVIOSO                                                                                               778
# ENFERMEDADES ENDOCRINAS, NUTRICIONALES Y METABOLICAS                                                                            616
# ENFERMEDADES DEL OIDO Y DE LA APOFISIS MASTOIDES                                                                                502
# ENFERMEDADES DEL OJO Y SUS ANEXOS                                                                                               369
# ENFERMEDADES DE LA SANGRE Y DE LOS ORGANOS HEMATOPOYETICOS, Y CIERTOS TRASTORNOS QUE AFECTAN EL MECANISMO DE LA INMUNIDAD       325
# FACTORES QUE INFLUYEN EN EL ESTADO DE SALUD Y CONTACTO CON LOS SERVICIOS DE SALUD                                               280
# CAUSAS EXTERNAS DE MORBILIDAD Y DE MORTALIDAD                                                                                   238
# CÓDIGOS PARA PROPÓSITOS ESPECIALES                                                                                              159
# MALFORMACIONES CONGENITAS, DEFORMIDADES Y ANOMALIAS CROMOSOMICAS                                                                125
# CIERTAS AFECCIONES ORIGINADAS EN EL PERIODO PERINATAL                                                                            16
# EMBARAZO, PARTO Y PUERPERIO                                                                                                       2
# Name: count, dtype: int64
# Dx_Relacionado1_Cod
# N390    163
# R509    152
# R11X    150
# R104    126
# I10X    116
#        ...
# C719      1
# B54X      1
# S360      1
# Q699      1
# K002      1
# Name: count, Length: 1053, dtype: int64
# Dx_Relacionado1
# OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS      126
# INFECCION DE VIAS URINARIAS  SITIO NO ESPECIFICADO    119
# FIEBRE  NO ESPECIFICADA                               110
# NAUSEA Y VOMITO                                       103
# CONTUSION DE LA RODILLA                                94
#                                                      ...
# MELANOMA MALIGNO DE SITIOS CONTIGUOS DE LA PIEL         1
# DERRAME ARTICULAR                                       1
# OTROS TRASTORNOS ESPECIFICADOS DEL PARPADO              1
# OTROS GLAUCOMAS                                         1
# ANOMALIAS DEL TAMANO Y DE LA FORMA DEL DIENTE           1
# Name: count, Length: 1156, dtype: int64
# Dx_Relacionado2_Cod_
# I10X    74
# R509    66
# Z038    41
# E86X    39
# S800    38
#         ..
# D630     1
# S208     1
# Y579     1
# S341     1
# C957     1
# Name: count, Length: 473, dtype: int64
# Dx_Relacionado2
# FIEBRE  NO ESPECIFICADA                                        57
# HIPERTENSION ESENCIAL (PRIMARIA)                               53
# OBSERVACION POR SOSPECHA DE OTRAS ENFERMEDADES Y AFECCIONES    41
# CONTUSION DE LA RODILLA                                        38
# OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS               35
#                                                                ..
# COLANGITIS                                                      1
# TRAUMATISMO DE LA MEDULA ESPINAL  NIVEL NO ESPECIFICADO         1
# FLEBITIS Y TROMBOFLEBITIS DE SITIO NO ESPECIFICADO              1
# OTRAS URTICARIAS                                                1
# OTRAS LEUCEMIAS DE CELULAS DE TIPO NO ESPECIFICADO              1
# Name: count, Length: 501, dtype: int64
# Dx_Relacionado3_Cod
# Z038    209
# I10X     36
# S800     13
# R509     13
# M796     12
#        ...
# S818      1
# I709      1
# J930      1
# I482      1
# S727      1
# Name: count, Length: 376, dtype: int64
# Dx_Relacionado3
# OBSERVACION POR SOSPECHA DE OTRAS ENFERMEDADES Y AFECCIONES            209
# HIPERTENSION ESENCIAL (PRIMARIA)                                        26
# CONTUSION DE LA RODILLA                                                 13
# OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS                        11
# DISNEA                                                                  11
#                                                                       ...
# TRASTORNO DE NERVIO CRANEAL  NO ESPECIFICADO                             1
# CHASQUIDO DE LA CADERA                                                   1
# INFECCION LOCAL DE LA PIEL Y DEL TEJIDO SUBCUTANEO  NO ESPECIFICADA      1
# PARO CARDIACO  NO ESPECIFICADO                                           1
# FRACTURAS MULTIPLES DEL FEMUR                                            1
# Name: count, Length: 402, dtype: int64
# Unidad
# Años     38768
# Meses      936
# Días        41
# Name: count, dtype: int64
# Grupo_Edad
# 1-4      3301
# 70-74    2929
# 65-69    2887
# 75-79    2863
# 5-9      2717
# 60-64    2615
# 80-84    2376
# 55-59    2330
# 20-24    1930
# 25-29    1891
# 30-34    1798
# 50-54    1712
# 10-14    1678
# 85-89    1672
# 40-44    1649
# 35-39    1630
# 45-49    1512
# > 90     1210
# 15-19    1038
# 0           1
# Name: count, dtype: int64
# Paciente_Sexo
# MASCULINO    20039
# FEMENINO     19706
# Name: count, dtype: int64
# Clasificacion_1_Triaje_Enfermeria_
# TRIAJE 3     28692
# TRIAJE 2      7565
# NO APLICA     2857
# TRIAJE 1       294
# TRIAJE 4       278
# TRIAJE 5        51
# Name: count, dtype: int64
# Clasificacion_Urg_(Nivel)Enfermeria_
# III. URGENCIA           28652
# II. EMERGENCIA           7559
# NO APLICA                2927
# I. RESUCITACION           290
# IV.URGENCIA DIFERIDA      269
# V. NO URGENTE              48
# Name: count, dtype: int64
# Ubicacion__Urgencias
# OBSERVACION        21754
# XPRESS             13371
# ALTA                4083
# HOSPITALIZACION      484
# XPress                45
# Name: count, dtype: int64
# Causa_Externa__(Riesgo)
# ENFERMEDAD GENERAL        35696
# ACCIDENTE DE TRANSITO      2956
# ACCIDENTE DE TRABAJO        842
# OTRO TIPO DE ACCIDENTE      170
# LESIÓN POR AGRESIÓN          25
# OTRA                         24
# ENFERMEDAD PROFESIONAL       16
# SOSPECHA ABUSO SEXUAL        10
# ACCIDENTE RÁBICO              6
# Name: count, dtype: int64
# Modalidad_Atencion
# URGENCIAS    31864
# REMITIDO      7184
# REMITIDOS      689
# Name: count, dtype: int64
# Ubicación_Triaje
# CONSULTORIO 1               12774
# XPRESS                       7712
# CONSULTORIO PEDIATRIA        7542
# CONSULTORIO 4                5749
# TRAUMA                       5285
# UDEA                          574
# CONSULTORIO ONCOLOGIA          42
# SAI ADULTO                     22
# CONSULTORIO 1 MAGISTERIO       21
# CONSULTORIO 2                  12
# CONSULTORIO 3                   6
# TAMIZAJE COVID                  4
# XPress                          2
# Name: count, dtype: int64
# Tiempo_Duracion_Diligenciamiento_F3
# 0        3876
# 0        2942
# 21:27      32
# 11:12      31
# 9:51       30
#          ...
# 52:36       1
# 43:22       1
# 39:51       1
# 49:45       1
# 55:16       1
# Name: count, Length: 2998, dtype: int64
# Triaje_Re-clasificado
# NO    30241
# SI     9504
# Name: count, dtype: int64
# Grupo_Poblacional
# POBLACIÓN GENERAL              21070
# 0                              18236
# HABITANTE DE CALLE               305
# VICTIMA DE CONFLICTO ARMADO      127
# REINTEGRADO O DESMOVILIZADO        3
# 3148207739                         1
# Name: count, dtype: int64
# Pertenencia_Etnica
# OTRAS ETNIAS                                                     37148
# NEGRO (A). MULATO (A). AFROCOLOMBIANO (A) O AFRO DESCENDIENTE     2127
# RROM (GITANO)                                                      234
# INDÍGENA                                                           172
# RAIZAL (ARCHIPIELAGO DE SAN ANDRES Y PROVIDENCIA)                   43
# PALANQUERO DE SAN BASILIO                                           12
# Name: count, dtype: int64
# ALTO_COSTO
# ZNO ALTO COSTO         37916
# CANCER                   928
# DIABETES                 318
# HIPERTENSION             209
# RENAL                    202
# TUBERCULOSIS              68
# VIH                       51
# ARTRITIS REUMATOIDE       22
# GESTANTES                  6
# HEMOFILIA                  4
# HEPATITIS C                1
# Name: count, dtype: int64

# %%
#valores nulos por variables
null_counts = df.isnull().sum()
for columna in df.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# COD: 0
# DESCRIPCION: 0
# Año: 0
# Mes: 0
# Paciente_Tipo_Identificacion: 0
# Nro_Atencion: 0
# Servicio_Admite: 0
# Servicio_Anterior: 7519
# Servicio_Egreso: 0
# Tipo_Egreso_(INTERNACION): 0
# Paciente_Entidad_Responsable_Pago: 0
# Paciente_Modalidad_Contrato: 0
# Paciente_Regimen_Afiliacion: 6
# Urg_Fecha_(Camara): 0
# Urg_Fecha_Ingreso: 0
# Urg_Fecha_Triaje: 2653
# Urg_Fecha_Consulta_F3: 0
# Dias_(Camara_-_F3): 1
# Horas_(Camara_-_F3): 1
# Minutos_(Camara_-_F3): 0
# Urg_Demora1_Consulta_(Minutos): 0
# Dias_(Camara_-_Triaje): 0
# Horas_(Camara_-_Triaje): 0
# Urg_Demora_Triaje_(Minutos): 0
# Dias_(Triaje_-_F3): 0
# Horas_(Triaje_-_F3): 0
# Minutos_(Triaje_-_F3): 0
# Urg_Demora2_Consulta_(Minutos): 0
# Profesional_Especialidad: 0
# Dx_Principal_Tipo_: 2
# Dx_Principal_Cod: 0
# Dx_Principal: 0
# Dx_Principal_Capitulo_Cod: 22
# Dx_Principal_Capitulo: 22
# Dx_Principal_Cod.1: 22
# Dx_Principal.1: 22
# Dx_Relacionado1_Cod: 34423
# Dx_Relacionado1: 34423
# Dx_Relacionado2_Cod_: 38289
# Dx_Relacionado2: 38289
# Dx_Relacionado3_Cod: 38800
# Dx_Relacionado3: 38800
# Paciente_Edad: 0
# Unidad: 0
# Grupo_Edad: 6
# Paciente_Sexo: 0
# Clasificacion_1_Triaje_Enfermeria_: 8
# Clasificacion_Urg_(Nivel)Enfermeria_: 0
# Ubicacion__Urgencias: 8
# Causa_Externa__(Riesgo): 0
# Modalidad_Atencion: 8
# Ubicación_Triaje: 0
# Profesional_Identificacion: 8
# Tiempo_Duracion_Diligenciamiento_F3: 9565
# Hora_Diligenciamiento_F3: 1
# Dias: 1
# Horas: 1
# Minutos: 1
# Triaje_Re-clasificado: 0
# Tiempo_Egreso_Urgencias: 10925
# Tiempo_Traslado_Hospitalizacion: 18648
# Tiempo_Cirugia: 21645
# Tiempo_Resolutividad_Hosp: 17236
# Tiempo_Resolutividad_Cx: 22484
# Tiempo_Resolutividad_Alta: 14544
# Tiempo_Resolutividad_Total: 0
# Urgencia_Xpress_F3: 0
# Grupo_Poblacional: 3
# Pertenencia_Etnica: 9
# ALTO_COSTO: 20

# %%
# Visualizar la distribución de variables numéricas
#for columna in df.select_dtypes(include=['float64', 'int64','bool']).columns:
    #sns.histplot(df[columna], kde=True)
    #plt.title(f'Distribución de {columna}')
    #plt.show()

# %%
# Aplicar one-hot encoding a la columna 'DESCRIPCION'
datos_encoded = pd.get_dummies(df, columns=['DESCRIPCION'])

grupo_edad_map = {
    '0': 0,
    '1-4': 2.5,
    '5-9': 7,
    '10-14': 12,
    '15-19': 17,
    '20-24': 22,
    '25-29': 27,
    '30-34': 32,
    '35-39': 37,
    '40-44': 42,
    '45-49': 47,
    '50-54': 52,
    '55-59': 57,
    '60-64': 62,
    '65-69': 67,
    '70-74': 72,
    '75-79': 77,
    '80-84': 82,
    '85-89': 87,
    '> 90': 95  # Tomando el valor medio para esta categoría
}

df['Grupo_Edad'] = df['Grupo_Edad'].map(grupo_edad_map)

correlacion = datos_encoded[['Grupo_Edad', 'Paciente_Edad', 'DESCRIPCION_URGENCIAS ADULTO', 'DESCRIPCION_URGENCIAS PEDIATRICAS']].corr()

correlacion
# Out:
#                                    Grupo_Edad  Paciente_Edad  \
# Grupo_Edad                           1.000000       0.998594
# Paciente_Edad                        0.998594       1.000000
# DESCRIPCION_URGENCIAS ADULTO         0.723769       0.727166
# DESCRIPCION_URGENCIAS PEDIATRICAS   -0.723769      -0.727166
#
#                                    DESCRIPCION_URGENCIAS ADULTO  \
# Grupo_Edad                                             0.723769
# Paciente_Edad                                          0.727166
# DESCRIPCION_URGENCIAS ADULTO                           1.000000
# DESCRIPCION_URGENCIAS PEDIATRICAS                     -1.000000
#
#                                    DESCRIPCION_URGENCIAS PEDIATRICAS
# Grupo_Edad                                                 -0.723769
# Paciente_Edad                                              -0.727166
# DESCRIPCION_URGENCIAS ADULTO                               -1.000000
# DESCRIPCION_URGENCIAS PEDIATRICAS                           1.000000

# %% [markdown]
# Entre DESCRIPCION_URGENCIAS ADULTO y Grupo Edad (Numérico) hay una correlación positiva moderada de aproximadamente 0.72. Esto sugiere que las urgencias clasificadas como "ADULTO" tienden a estar asociadas con grupos de edad mayores, lo cual tiene sentido intuitivamente.
#
# Entre DESCRIPCION_URGENCIAS PEDIATRICAS y Grupo Edad (Numérico) hay una correlación negativa moderada de aproximadamente -0.72. Esto indica que las urgencias clasificadas como "PEDIATRICAS" tienden a estar asociadas con grupos de edad más jóvenes.
#
# Entre DESCRIPCION_URGENCIAS ADULTO y Paciente Edad y entre DESCRIPCION_URGENCIAS PEDIATRICAS y Paciente Edad, las correlaciones son las mismas pero con signo negativo, lo que tiene sentido ya que estas variables son opuestas entre sí (una indica urgencias para adultos y la otra para pediátricas).

# %% [markdown]
# despúes de conocer la distribución de los datos se encuentran los siguientes puntos, se tienen valores de tipo:
# int64, object, float65 y bool, el dataFrame tiene **70 columnas**, enumeradas del 0 al 69, y **39745 filas**.
#
# primero se hace una descripción para saber la frecuencia de los valores para las variAbles categoricas(**'OBJECT', 'bool'**), y se visualiza la distribución de las varibles numericas (**float64, int64**), de lo anterior y una previa revisión de los datos manualmente en excel. se resaltan los siguientes puntos importantes.
#
# **DESCRIPCION **(Tipo de urgencia): Hay una clara diferencia en la cantidad de urgencias atendidas entre urgencias de adultos y pediátricas, con un número significativamente mayor de urgencias para adultos.
#
# **Mes:** No parece haber una distribución uniforme de urgencias a lo largo del año. Algunos meses, como abril y marzo, tienen una cantidad considerablemente mayor de urgencias en comparación con otros.
#
# **Tipo de Identificación del Paciente:** La mayoría de los pacientes se identifican con cédula de ciudadanía (CC), seguidos por registros civiles (RC) y tarjetas de identidad (TI). lo cual tiene mucho sentido ya que el la mayor tipo de urgencia es de adultos, asi mmismo se observo que la distribución **paciente edad **y **grupo edad**  es mayor en un rango 18 a 100.
#
# **Servicio que admite:** La mayoría de las urgencias son atendidas en urgencias generales del sótano o en ningún servicio específico.
# **Servicio Anterior y Egreso :** Los servicios anteriores y los destinos de egreso son diversos, con una distribución que indica diferentes tipos de tratamientos y resultados.
# **Tipo de Egreso (Internación):** La mayoría de los pacientes son dados de alta médica, seguidos por remisiones a otras instituciones y fallecimientos.
#
# **Modalidad de Contrato del Paciente:** La mayoría de los pacientes están bajo el evento de atención, con un número mucho menor bajo PGP (Prestación de Garantía de Producto) y CAPITA.
# **Regimen de Afiliación del Paciente:** La mayoría de los pacientes están afiliados al régimen contributivo o subsidiado.
# **Profesional Especialidad: **Predominan las consultas de medicina general, seguidas por pediatría y urgenciología.
# Sexo del Paciente: La distribución de género es casi uniforme, con una ligera inclinación hacia los pacientes masculinos.se desprecia esta variable para el modelo. estos y la distribucion de edad del profesional se despreian debido a que no se considera que son relevantes para la predicción de hospitalización.
#
# **Diagnósticos Principales**: Los diagnósticos varían ampliamente, desde dolores abdominales hasta enfermedades específicas como infecciones urinarias y fiebres.
#
# **Clasificación de Triaje y Urgencia**: La mayoría de las urgencias clasificadas son de nivel III y II, lo que indica una distribución predominante de casos no críticos. esta variable se considera importante ya que puede aportar información relevante al modelo.
#
# **Ubicación de Urgencias y Triaje**: Las urgencias se distribuyen principalmente entre la observación y las áreas de Xpress, mientras que el triaje se realiza en consultorios y áreas de trauma. dado que esta variable ya me categoriza al paciente, en el sentido si va ser hospitalización. REVISAR
#
# **Grupo Poblacional y Pertenencia Étnica:** La mayoría de los pacientes son de población general y pertenecen a otras etnias. no se va a concisderar estas varibales para el modelo, dado que la información que brindan no es especificac o dice si esta relacionada con diagnosticos.
#
# **Alto Costo:** La mayoría de los casos no están clasificados como alto costo, con la mayoría de ellos etiquetados como "ZNO ALTO COSTO".
#
# al observar la distribución de la **hora, minutos y dias** de dilegenciamiento del f3 se observa que ambas tienen la misma tendencia para el caso de las dos primeras y en la ultima nunca se alcanza una valor unitarios, por lo que se decide solo utilizar la variable de minutos.
#
# se observa que para la variable de **modalidad de atención** se juntas los valores clasificados en remitido y remitos en una sola.
#
# **COD**: es el mimmo codigo ya que es el servicio de urgencias. un código de identificación no tiene un significado específico para el análisis de predicción de hospitalización, se desprecia.
#
#
# **Año**: todos los registros tienen el mismo valor para el año, no aporta variabilidad y se despreciarse.
#
# **Nro Atencion**: es un número aleatorio. este número no tiene relevancia para la predicción de hospitalización, se despreciarse.
#
# **Paciente Entidad Responsable Pago**: A menos que la entidad responsable de pago sea un factor relevante para la predicción de hospitalización (por ejemplo, si ciertas entidades tienen políticas que afectan la duración de la estadía), se desprecia por insuficiencia de información.
#
# **Profesional Identificacion**: la identificación del profesional no tiene un impacto directo en la predicción de hospitalización, se desprecia.
#
# **Dias (Triaje - F3),Horas (Triaje - F3), Minutos (Triaje - F3)**: estas variables representan el tiempo en un proceso específico, las dos ultimas presentan la misma distribución por lo que se decide utilizar minutos (Triaje - F3), para el modelo.
#
# **Horas (camara - F3), Minutos (camara - F3)**: estas variables representan el tiempo en un proceso específico, las presentan la misma distribución por lo que se decide utilizar minuto (camara - F3), para el modelo.
#
# **Dias (camara- triaje),Horas (camara - triaje)**: estas variables representan el tiempo en un proceso específico, las primer tiene un unico calor (0), por lo que se decide utilizar Horas (Triaje - F3), para el modelo.
#
#
# teniendo en cuenta lo anterior se hace una primera separación de las variables relevaNtes y despreciables:
#
# Primeras Variables Despreciadas para el Modelo:
# - Regimen de Afiliación del Paciente
# - Edad del Profesional
# - Profesional Especialidad
# - Sexo del Paciente
# - Grupo Poblacional y Pertenencia Étnica
# - COD
# - Año
# - Nro Atencion
# - Paciente Entidad Responsable Pago
# - Profesional Identificación
# - Dias (camara- triaje)
# - Tipo de Identificación del Paciente
# - grupo edad
# - Modalidad de Contrato del Paciente
# - Grupo Poblacional
# - Pertenencia étnica
# - Hora doiiigenciamiento f3
# - Dias diligenciamiento f3
# - Dias (Triaje - F3)
# - Horas (Triaje - F3)
# - Horas (camara - F3)
# - Dias (camara- triaje)
# - Dx Principal
# - Dx Principal Capitulo
# - Dx Principal.1
# - Dx Relacionado1
# - Dx Relacionado2
# - Dx Relacionado3
#
# Posteriormente se procede a analizar a mayor profundidad las variables.

# %% [markdown]
# De la literatura concluimos que Las fechas suelen ser redundantes en el contexto de predicciones basadas en períodos de tiempo relativos.
# En muchos casos, la información temporal ya está representada por variables derivadas como "Días (Camara - F3)" o "Minutos (Triaje - F3)", lo que hace que las fechas exactas sean innecesarias.
#
# Las fechas exactas, como el día específico de una consulta o el momento de una operación, generalmente no tienen un impacto directo en la predicción de si un paciente será hospitalizado o dado de alta.
#
# En lugar de usar fechas absolutas, los modelos de machine learning se benefician más de las duraciones y diferencias de tiempo que proporcionan una métrica más directa del estado del paciente y el flujo del proceso médico.
#
# Incluir fechas como variables en un modelo puede complicar el preprocesamiento y no aportar valor adicional.
# Las fechas requieren transformación adicional (por ejemplo, extraer día de la semana, mes, etc.), lo cual puede no ser necesario si ya se dispone de duraciones y tiempos relativos.

# %% [markdown]
# Los códigos de diagnóstico ya contienen toda la información necesaria sobre la naturaleza de la enfermedad o condición del paciente.
# Mantener tanto los códigos como los nombres de los diagnósticos introduce redundancia, lo que puede complicar el modelo sin aportar información adicional.
#
# Los códigos de diagnóstico son más consistentes y uniformes para el modelado, ya que son datos estructurados y categorizados de manera estándar.
# Los nombres de los diagnósticos pueden variar en longitud y formato, lo que puede introducir ruido en los datos.
#
# Los códigos de diagnóstico pueden ser fácilmente codificados (one-hot encoding) o utilizados directamente en el modelo, mientras que los nombres de los diagnósticos podrían requerir técnicas de procesamiento de texto más complejas.

# %%
columnas_eliminar_objetos = ['COD','Año','Mes','Paciente_Tipo_Identificacion',  'Nro_Atencion', 'Paciente_Entidad_Responsable_Pago',
                             'Paciente_Modalidad_Contrato','Paciente_Regimen_Afiliacion', 'Urg_Fecha_(Camara)','Urg_Fecha_Ingreso',
                             'Urg_Fecha_Triaje','Urg_Fecha_Consulta_F3' , 'Dias_(Camara_-_F3)','Horas_(Camara_-_F3)',
                             'Urg_Demora1_Consulta_(Minutos)', 'Dias_(Camara_-_Triaje)', 'Urg_Demora_Triaje_(Minutos)', 'Dias_(Triaje_-_F3)',
                             'Horas_(Triaje_-_F3)','Urg_Demora2_Consulta_(Minutos)','Profesional_Especialidad','Dx_Principal_Tipo_',
                             'Dx_Principal', 'Dx_Principal_Capitulo', 'Dx_Principal.1','Dx_Relacionado1','Dx_Relacionado2','Dx_Relacionado3', 'Paciente_Edad',
                             'Unidad', 'Grupo_Edad', 'Paciente_Sexo',  'Profesional_Identificacion', 'Dias', 'Horas', 'Grupo_Poblacional', 'Pertenencia_Etnica',
                             'ALTO_COSTO'
                             ]

# Crear un nuevo DataFrame eliminando las columnas
df_drop = df.drop(columns=columnas_eliminar_objetos)
df_drop
# Out:
#             DESCRIPCION             Servicio_Admite  \
# 0      URGENCIAS ADULTO  URGENCIAS GENERALES SÓTANO
# 1      URGENCIAS ADULTO                   NO APLICA
# 2      URGENCIAS ADULTO                   NO APLICA
# 3      URGENCIAS ADULTO             HOSPITALIZACIÓN
# 4      URGENCIAS ADULTO  URGENCIAS GENERALES SÓTANO
# ...                 ...                         ...
# 39740  URGENCIAS ADULTO  URGENCIAS GENERALES SÓTANO
# 39741  URGENCIAS ADULTO                   NO APLICA
# 39742  URGENCIAS ADULTO                   NO APLICA
# 39743  URGENCIAS ADULTO  URGENCIAS GENERALES SÓTANO
# 39744  URGENCIAS ADULTO                   NO APLICA
#
#                 Servicio_Anterior                Servicio_Egreso  \
# 0         PISO 7 UCI NEUROCIRUGÍA  PISO 8 MEDICINA INTERNA NORTE
# 1                       NO APLICA                      NO APLICA
# 2                       NO APLICA                      NO APLICA
# 3      CAMILLAS SALA 4  URGENCIAS  PISO 5 MEDICINA INTERNA NORTE
# 4      CAMILLAS SALA 2  URGENCIAS                     PISO 6 UCE
# ...                           ...                            ...
# 39740  CAMILLAS SALA 4  URGENCIAS               PISO 2 OCCIDENTE
# 39741                   NO APLICA                      NO APLICA
# 39742                   NO APLICA                      NO APLICA
# 39743                         NaN     CAMILLAS SALA 3  URGENCIAS
# 39744                   NO APLICA                      NO APLICA
#
#          Tipo_Egreso_(INTERNACION)  Minutos_(Camara_-_F3)  \
# 0                          FALLECE              26.633333
# 1                        NO APLICA              65.133333
# 2                        NO APLICA              82.050000
# 3                      ALTA MÉDICA               0.000000
# 4                      ALTA MÉDICA             116.850000
# ...                            ...                    ...
# 39740                  ALTA MÉDICA               0.000000
# 39741                    NO APLICA              40.900000
# 39742                    NO APLICA               0.000000
# 39743  REMISIÓN A OTRA INSTITUCIÓN              42.116667
# 39744                    NO APLICA              90.266667
#
#        Horas_(Camara_-_Triaje)  Minutos_(Triaje_-_F3) Dx_Principal_Cod  \
# 0                     0.008645              14.183333             I10X
# 1                     0.006580              55.650000             W540
# 2                     0.002238              78.833333             G510
# 3                     0.000000               0.000000             R224
# 4                     0.005968             108.250000             K922
# ...                        ...                    ...              ...
# 39740                 0.000000               0.000000             K409
# 39741                 0.004826              33.950000             S409
# 39742                 0.000000               0.000000             S528
# 39743                 0.003808              36.633333             N390
# 39744                 0.004699              83.500000             C56X
#
#       Dx_Principal_Capitulo_Cod  ... Minutos Triaje_Re-clasificado  \
# 0                           I10  ...    15.0                    NO
# 1                           W54  ...    56.0                    NO
# 2                           G51  ...    79.0                    NO
# 3                           R22  ...     0.0                    NO
# 4                           K92  ...   108.0                    SI
# ...                         ...  ...     ...                   ...
# 39740                       K40  ...    74.0                    NO
# 39741                       S40  ...    34.0                    NO
# 39742                       S52  ...    48.0                    NO
# 39743                       N39  ...    36.0                    NO
# 39744                       C56  ...    83.0                    NO
#
#       Tiempo_Egreso_Urgencias Tiempo_Traslado_Hospitalizacion Tiempo_Cirugia  \
# 0                       190.0                            34.0            0.0
# 1                        52.0                             0.0            0.0
# 2                         0.0                             0.0            0.0
# 3                      1432.0                             0.0         6053.0
# 4                       384.0                            69.0            0.0
# ...                       ...                             ...            ...
# 39740                   712.0                            70.0         3459.0
# 39741                   159.0                             0.0            0.0
# 39742                   116.0                             0.0            0.0
# 39743                  1508.0                             0.0            0.0
# 39744                  2731.0                             0.0            0.0
#
#       Tiempo_Resolutividad_Hosp Tiempo_Resolutividad_Cx  \
# 0                          84.0                     0.0
# 1                           0.0                     0.0
# 2                           0.0                     0.0
# 3                           0.0                  1092.0
# 4                         286.0                     0.0
# ...                         ...                     ...
# 39740                       0.0                   162.0
# 39741                       0.0                     0.0
# 39742                       0.0                     0.0
# 39743                     838.0                     0.0
# 39744                       0.0                     0.0
#
#       Tiempo_Resolutividad_Alta Tiempo_Resolutividad_Total Urgencia_Xpress_F3
# 0                           0.0                         84               True
# 1                          34.0                         34              False
# 2                           0.0                          0              False
# 3                           0.0                       1092               True
# 4                           0.0                        286              False
# ...                         ...                        ...                ...
# 39740                       0.0                        162               True
# 39741                     133.0                        133              False
# 39742                     100.0                        100               True
# 39743                       0.0                        838              False
# 39744                    2583.0                       2583              False
#
# [39745 rows x 32 columns]

# %%
# valores nulos por variables
null_counts = df_drop.isnull().sum()
for columna in df_drop.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# DESCRIPCION: 0
# Servicio_Admite: 0
# Servicio_Anterior: 7519
# Servicio_Egreso: 0
# Tipo_Egreso_(INTERNACION): 0
# Minutos_(Camara_-_F3): 0
# Horas_(Camara_-_Triaje): 0
# Minutos_(Triaje_-_F3): 0
# Dx_Principal_Cod: 0
# Dx_Principal_Capitulo_Cod: 22
# Dx_Principal_Cod.1: 22
# Dx_Relacionado1_Cod: 34423
# Dx_Relacionado2_Cod_: 38289
# Dx_Relacionado3_Cod: 38800
# Clasificacion_1_Triaje_Enfermeria_: 8
# Clasificacion_Urg_(Nivel)Enfermeria_: 0
# Ubicacion__Urgencias: 8
# Causa_Externa__(Riesgo): 0
# Modalidad_Atencion: 8
# Ubicación_Triaje: 0
# Tiempo_Duracion_Diligenciamiento_F3: 9565
# Hora_Diligenciamiento_F3: 1
# Minutos: 1
# Triaje_Re-clasificado: 0
# Tiempo_Egreso_Urgencias: 10925
# Tiempo_Traslado_Hospitalizacion: 18648
# Tiempo_Cirugia: 21645
# Tiempo_Resolutividad_Hosp: 17236
# Tiempo_Resolutividad_Cx: 22484
# Tiempo_Resolutividad_Alta: 14544
# Tiempo_Resolutividad_Total: 0
# Urgencia_Xpress_F3: 0

# %% [markdown]
# ### **Valores nulos**

# %%
# Seleccionar columnas de tipo numericas
df_numericas = df_drop.select_dtypes(include=['int64', 'float64'])
null_counts = df_numericas.isnull().sum()
for columna in df_numericas.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# Minutos_(Camara_-_F3): 0
# Horas_(Camara_-_Triaje): 0
# Minutos_(Triaje_-_F3): 0
# Hora_Diligenciamiento_F3: 1
# Minutos: 1
# Tiempo_Egreso_Urgencias: 10925
# Tiempo_Traslado_Hospitalizacion: 18648
# Tiempo_Cirugia: 21645
# Tiempo_Resolutividad_Hosp: 17236
# Tiempo_Resolutividad_Cx: 22484
# Tiempo_Resolutividad_Alta: 14544
# Tiempo_Resolutividad_Total: 0

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)

# %%
# Se hace la importación de la librería
from sklearn.impute import KNNImputer

# %%
#Se eliminan los valores nulos de las variables numericas
imp = KNNImputer(n_neighbors=3 , weights='uniform')
X = df_numericas
X = imp.fit_transform(X)
df_numericas_imputer = pd.DataFrame(X, columns=df_numericas.columns)
df_numericas_imputer
# Out:
#        Minutos_(Camara_-_F3)  Horas_(Camara_-_Triaje)  Minutos_(Triaje_-_F3)  \
# 0                  26.633333                 0.008645              14.183333
# 1                  65.133333                 0.006580              55.650000
# 2                  82.050000                 0.002238              78.833333
# 3                   0.000000                 0.000000               0.000000
# 4                 116.850000                 0.005968             108.250000
# ...                      ...                      ...                    ...
# 39740               0.000000                 0.000000               0.000000
# 39741              40.900000                 0.004826              33.950000
# 39742               0.000000                 0.000000               0.000000
# 39743              42.116667                 0.003808              36.633333
# 39744              90.266667                 0.004699              83.500000
#
#        Hora_Diligenciamiento_F3  Minutos  Tiempo_Egreso_Urgencias  \
# 0                      0.862616     15.0                    190.0
# 1                      0.638356     56.0                     52.0
# 2                      0.821887     79.0                      0.0
# 3                      0.712373      0.0                   1432.0
# 4                      0.503935    108.0                    384.0
# ...                         ...      ...                      ...
# 39740                  0.141713     74.0                    712.0
# 39741                  0.414919     34.0                    159.0
# 39742                  0.507465     48.0                    116.0
# 39743                  0.387384     36.0                   1508.0
# 39744                  0.595729     83.0                   2731.0
#
#        Tiempo_Traslado_Hospitalizacion  Tiempo_Cirugia  \
# 0                                 34.0             0.0
# 1                                  0.0             0.0
# 2                                  0.0             0.0
# 3                                  0.0          6053.0
# 4                                 69.0             0.0
# ...                                ...             ...
# 39740                             70.0          3459.0
# 39741                              0.0             0.0
# 39742                              0.0             0.0
# 39743                              0.0             0.0
# 39744                              0.0             0.0
#
#        Tiempo_Resolutividad_Hosp  Tiempo_Resolutividad_Cx  \
# 0                           84.0                      0.0
# 1                            0.0                      0.0
# 2                            0.0                      0.0
# 3                            0.0                   1092.0
# 4                          286.0                      0.0
# ...                          ...                      ...
# 39740                        0.0                    162.0
# 39741                        0.0                      0.0
# 39742                        0.0                      0.0
# 39743                      838.0                      0.0
# 39744                        0.0                      0.0
#
#        Tiempo_Resolutividad_Alta  Tiempo_Resolutividad_Total
# 0                            0.0                        84.0
# 1                           34.0                        34.0
# 2                            0.0                         0.0
# 3                            0.0                      1092.0
# 4                            0.0                       286.0
# ...                          ...                         ...
# 39740                        0.0                       162.0
# 39741                      133.0                       133.0
# 39742                      100.0                       100.0
# 39743                        0.0                       838.0
# 39744                     2583.0                      2583.0
#
# [39745 rows x 12 columns]

# %%
null_counts = df_numericas_imputer.isnull().sum()
for columna in df_numericas_imputer.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# Minutos_(Camara_-_F3): 0
# Horas_(Camara_-_Triaje): 0
# Minutos_(Triaje_-_F3): 0
# Hora_Diligenciamiento_F3: 0
# Minutos: 0
# Tiempo_Egreso_Urgencias: 0
# Tiempo_Traslado_Hospitalizacion: 0
# Tiempo_Cirugia: 0
# Tiempo_Resolutividad_Hosp: 0
# Tiempo_Resolutividad_Cx: 0
# Tiempo_Resolutividad_Alta: 0
# Tiempo_Resolutividad_Total: 0

# %%
# Seleccionar columnas de tipo object
df_objetos = df_drop.select_dtypes(include=['object','bool'])
null_counts = df_objetos.isnull().sum()
for columna in df_objetos.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# DESCRIPCION: 0
# Servicio_Admite: 0
# Servicio_Anterior: 7519
# Servicio_Egreso: 0
# Tipo_Egreso_(INTERNACION): 0
# Dx_Principal_Cod: 0
# Dx_Principal_Capitulo_Cod: 22
# Dx_Principal_Cod.1: 22
# Dx_Relacionado1_Cod: 34423
# Dx_Relacionado2_Cod_: 38289
# Dx_Relacionado3_Cod: 38800
# Clasificacion_1_Triaje_Enfermeria_: 8
# Clasificacion_Urg_(Nivel)Enfermeria_: 0
# Ubicacion__Urgencias: 8
# Causa_Externa__(Riesgo): 0
# Modalidad_Atencion: 8
# Ubicación_Triaje: 0
# Tiempo_Duracion_Diligenciamiento_F3: 9565
# Triaje_Re-clasificado: 0
# Urgencia_Xpress_F3: 0

# %%
#Obtener la salida
df_salida = pd.get_dummies(df_objetos['Servicio_Admite'], prefix_sep='_')
#df_salida['HOSPITALIZACIÓN']
df_objetos = df_objetos.drop(columns=['Servicio_Admite'])

# %%
#Colocar los valores correspondientes a Dx_Principal_Capitulo_Cod, si el valor es nulo
df_objetos['Dx_Principal_Capitulo_Cod'] = None

for i, elem in enumerate(df_objetos['Dx_Principal_Cod']):
    if elem[-1].isdigit():
        df_objetos.at[i, 'Dx_Principal_Capitulo_Cod'] = None
    else:
        df_objetos.at[i, 'Dx_Principal_Capitulo_Cod'] = elem
df_objetos['Dx_Principal_Capitulo_Cod'] = df_objetos['Dx_Principal_Cod'].apply(lambda x: x[:-1] if x[-1].isdigit() else x)

# %%
#Colocar los valores correspondientes a Dx_Principal_Cod.1, si el valor es nulo o el Dx_Principal_Cod si no existe en la lista de Dx_Principal_Cod.1 (son 7 A90X,M45X, M725,R501)
mapping = df_objetos.dropna(subset=['Dx_Principal_Cod.1']).set_index('Dx_Principal_Cod')['Dx_Principal_Cod.1'].to_dict()

df_objetos['Dx_Principal_Cod.1'] = df_objetos.apply(
    lambda row: mapping.get(row['Dx_Principal_Cod'], row['Dx_Principal_Cod']) if pd.isnull(row['Dx_Principal_Cod.1']) else row['Dx_Principal_Cod.1'],
    axis=1
)

# %%
#Si no tiene diagnostico relacionado colocar 0
df_objetos['Dx_Relacionado1_Cod'] = df_objetos['Dx_Relacionado1_Cod'].fillna(0)
df_objetos['Dx_Relacionado2_Cod_'] = df_objetos['Dx_Relacionado2_Cod_'].fillna(0)
df_objetos['Dx_Relacionado3_Cod'] = df_objetos['Dx_Relacionado3_Cod'].fillna(0)

# %%
# Codificación ordinal, hay un orden del triaje
orden = ['TRIAJE 5', 'TRIAJE 4', 'TRIAJE 3', 'TRIAJE 2', 'TRIAJE 1','NO APLICA']
df_objetos2= df_objetos['Clasificacion_1_Triaje_Enfermeria_'].map({cat: idx for idx, cat in enumerate(orden)})
df_objetos = df_objetos.drop(columns=['Clasificacion_1_Triaje_Enfermeria_'])

# %%
#Imputacion de las variables que tienen valores nulos
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

cols_to_impute = ['Servicio_Anterior','Ubicacion__Urgencias', 'Modalidad_Atencion',
                  'Tiempo_Duracion_Diligenciamiento_F3']

df_objetos[cols_to_impute] = imp.fit_transform(df_objetos[cols_to_impute])

# %%
null_counts = df_objetos.isnull().sum()
for columna in df_objetos.columns:
    print(f"{columna}: {null_counts[columna]}")
# Out:
# DESCRIPCION: 0
# Servicio_Anterior: 0
# Servicio_Egreso: 0
# Tipo_Egreso_(INTERNACION): 0
# Dx_Principal_Cod: 0
# Dx_Principal_Capitulo_Cod: 0
# Dx_Principal_Cod.1: 0
# Dx_Relacionado1_Cod: 0
# Dx_Relacionado2_Cod_: 0
# Dx_Relacionado3_Cod: 0
# Clasificacion_Urg_(Nivel)Enfermeria_: 0
# Ubicacion__Urgencias: 0
# Causa_Externa__(Riesgo): 0
# Modalidad_Atencion: 0
# Ubicación_Triaje: 0
# Tiempo_Duracion_Diligenciamiento_F3: 0
# Triaje_Re-clasificado: 0
# Urgencia_Xpress_F3: 0

# %%
# Codificar las columnas categóricas utilizando One-Hot Encoding
df_objetos = pd.get_dummies(df_objetos)

num_columns = len(df_objetos.columns)
random_integers = np.random.randint(1, 100, num_columns)

for i, column in enumerate(df_objetos.columns):
    df_objetos[column] *= random_integers[i]

# %%
df_objetos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39745 entries, 0 to 39744
# Columns: 8615 entries, Urgencia_Xpress_F3 to Triaje_Re-clasificado_SI
# dtypes: int32(8615)
# memory usage: 1.3 GB

# %% [markdown]
# ### **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split , KFold

# %% [markdown]
# ####  Características o Variables de entrada

# %%
df_concat = pd.concat([df_numericas_imputer, df_objetos, df_objetos2], axis=1)
X = df_concat.iloc[:,:]
X.head(5)
# Out:
#    Minutos_(Camara_-_F3)  Horas_(Camara_-_Triaje)  Minutos_(Triaje_-_F3)  \
# 0              26.633333                 0.008645              14.183333
# 1              65.133333                 0.006580              55.650000
# 2              82.050000                 0.002238              78.833333
# 3               0.000000                 0.000000               0.000000
# 4             116.850000                 0.005968             108.250000
#
#    Hora_Diligenciamiento_F3  Minutos  Tiempo_Egreso_Urgencias  \
# 0                  0.862616     15.0                    190.0
# 1                  0.638356     56.0                     52.0
# 2                  0.821887     79.0                      0.0
# 3                  0.712373      0.0                   1432.0
# 4                  0.503935    108.0                    384.0
#
#    Tiempo_Traslado_Hospitalizacion  Tiempo_Cirugia  Tiempo_Resolutividad_Hosp  \
# 0                             34.0             0.0                       84.0
# 1                              0.0             0.0                        0.0
# 2                              0.0             0.0                        0.0
# 3                              0.0          6053.0                        0.0
# 4                             69.0             0.0                      286.0
#
#    Tiempo_Resolutividad_Cx  ...  Tiempo_Duracion_Diligenciamiento_F3_9:58  \
# 0                      0.0  ...                                         0
# 1                      0.0  ...                                         0
# 2                      0.0  ...                                         0
# 3                   1092.0  ...                                         0
# 4                      0.0  ...                                         0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:59  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:6  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:60  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:7  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:8  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    Tiempo_Duracion_Diligenciamiento_F3_9:9  Triaje_Re-clasificado_NO  \
# 0                                        0                        50
# 1                                        0                        50
# 2                                        0                        50
# 3                                        0                        50
# 4                                        0                         0
#
#    Triaje_Re-clasificado_SI  Clasificacion_1_Triaje_Enfermeria_
# 0                         0                                 3.0
# 1                         0                                 2.0
# 2                         0                                 2.0
# 3                         0                                 5.0
# 4                         7                                 2.0
#
# [5 rows x 8628 columns]

# %% [markdown]
# ####  Etiquetas, Clases o Salida

# %%
y = df_salida.iloc[:,4]
y.head(5)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: HOSPITALIZACIÓN, dtype: bool

# %%
#Separación de muestras para train y test
X_train , X_test , y_train , y_test = train_test_split(X, y)

print("Train: ",X_train.shape , y_train.shape)
print("Test: ",X_test.shape , y_test.shape)
# Out:
# Train:  (29808, 8628) (29808,)
# Test:  (9937, 8628) (9937,)

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
       'n_estimators': [10, 50, 70],
       'max_depth': [None, 10, 20, 30],
              }
dt = RandomForestClassifier(random_state=123 , n_jobs=-1)
clf = GridSearchCV(dt, parameters , cv=5 , verbose=1)
clf.fit(X_train, y_train)
clf.best_estimator_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=123)

# %%
clf.best_params_
# Out:
# {'max_depth': None, 'n_estimators': 50}

# %%
#Entrenar el modelo de Random Forest
best_model = RandomForestClassifier( n_estimators=50, max_depth=None, n_jobs=-1, random_state=123
                            ## Usar los mejores parámetros encontradas en el gridseach anterior.
                            )
best_model.fit(X_train , y_train)
best_model.score(X_test , y_test)
# Out:
# 0.9838985609338835

# %%
# Hacer predicciones con el modelo entrenado
preds = best_model.predict(X_test)

# %%
#Evaluar el modelo
acc = accuracy_score(y_test , preds)
acc
# Out:
# 0.9838985609338835

# %%
# Verificar el número de características en el modelo
num_features = len(best_model.feature_importances_)
print(f"Number of features: {num_features}")
# Out:
# Number of features: 8628

# %%
# Obtener las etiquetas de las columnas del DataFrame procesado
feature_names = df_concat.columns

# Verificar la longitud de feature_names
print(f"Number of feature names: {len(feature_names)}")
# Out:
# Number of feature names: 8628

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score

# %%
labels=["Hospitalizado", "No hospitalizado"]
mc_test = confusion_matrix(y_test,preds)
fig , ax = plt.subplots(figsize=(7,5))
sns.heatmap(mc_test ,cmap='Blues',annot=True , xticklabels=labels, yticklabels=labels)
plt.xlabel('Valores de verdad')
plt.ylabel('Predicciones')
plt.show()

# %% [markdown]
# **CONSIDERACIONES FINALES**

# %% [markdown]
# Para las variables con valores nulos pueden utilizar técnicas estadísticas como la media, mediana o la moda.
#
# Las variables numéricas como tiempos y minutos se escalaran para normalizar los datos. Las variables categóricas como "Clasificación 1 Triaje Enfermería", "Ubicación Urgencias", etc.,se convertiran en variables dummy.
#
# Se utilizara modelos como Random Forest para determinar la importancia de cada variable.

# %% [markdown]
# # Guardamos el modelo

# %%
import pickle
pickle.dump(dt, open('training_model.pkl', 'wb'))

# %% [markdown]
# Probamos el modelo volviendo a cargar los dato

# %%
dt2 = pickle.load(open('training_model.pkl', 'rb'))

# %%
X_test
# Out:
#        Minutos_(Camara_-_F3)  Horas_(Camara_-_Triaje)  Minutos_(Triaje_-_F3)  \
# 8399                0.000000                 0.000000               0.000000
# 21317               0.000000                 0.000000               0.000000
# 36542               0.000000                 0.000000               0.000000
# 19134               0.000000                 0.000000               0.000000
# 6545                0.000000                 0.000000               0.000000
# ...                      ...                      ...                    ...
# 3856               64.183333                 0.022360              31.983333
# 1696              182.000000                 0.008038             170.433333
# 2217               66.216667                 0.011008              50.366667
# 21486               0.000000                 0.000000               0.000000
# 14412              88.983333                 0.010509              73.850000
#
#        Hora_Diligenciamiento_F3  Minutos  Tiempo_Egreso_Urgencias  \
# 8399                   0.973380      0.0                 0.000000
# 21317                  0.822269      0.0              7636.000000
# 36542                  0.576296     10.0               218.000000
# 19134                  0.453102    102.0              1146.333333
# 6545                   0.842245      0.0               854.000000
# ...                         ...      ...                      ...
# 3856                   0.651377     31.0               566.000000
# 1696                   0.724502    171.0              3210.000000
# 2217                   0.861146     51.0               184.000000
# 21486                  0.085428      0.0                 0.000000
# 14412                  0.870463     74.0               634.000000
#
#        Tiempo_Traslado_Hospitalizacion  Tiempo_Cirugia  \
# 8399                       7058.333333      125.000000
# 21317                        20.000000     2567.000000
# 36542                         0.000000        0.000000
# 19134                      5082.000000     2977.000000
# 6545                         19.000000     6017.666667
# ...                                ...             ...
# 3856                         47.000000        7.000000
# 1696                         78.000000        0.000000
# 2217                          0.000000        0.000000
# 21486                      6633.333333        0.000000
# 14412                        17.000000     1347.000000
#
#        Tiempo_Resolutividad_Hosp  Tiempo_Resolutividad_Cx  ...  \
# 8399                    0.000000              5289.333333  ...
# 21317                 556.000000               544.000000  ...
# 36542                   0.000000                 0.000000  ...
# 19134                2093.666667              2091.000000  ...
# 6545                  723.000000               722.666667  ...
# ...                          ...                      ...  ...
# 3856                  395.000000                 0.000000  ...
# 1696                 1049.000000                 0.000000  ...
# 2217                    0.000000                 0.000000  ...
# 21486                   0.000000                 0.000000  ...
# 14412                 215.000000                 0.000000  ...
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:58  \
# 8399                                          0
# 21317                                         0
# 36542                                         0
# 19134                                         0
# 6545                                          0
# ...                                         ...
# 3856                                          0
# 1696                                          0
# 2217                                          0
# 21486                                         0
# 14412                                         0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:59  \
# 8399                                          0
# 21317                                         0
# 36542                                         0
# 19134                                         0
# 6545                                          0
# ...                                         ...
# 3856                                          0
# 1696                                          0
# 2217                                          0
# 21486                                         0
# 14412                                         0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:6  \
# 8399                                         0
# 21317                                        0
# 36542                                        0
# 19134                                        0
# 6545                                         0
# ...                                        ...
# 3856                                         0
# 1696                                         0
# 2217                                         0
# 21486                                        0
# 14412                                        0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:60  \
# 8399                                          0
# 21317                                         0
# 36542                                         0
# 19134                                         0
# 6545                                          0
# ...                                         ...
# 3856                                          0
# 1696                                          0
# 2217                                          0
# 21486                                         0
# 14412                                         0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:7  \
# 8399                                         0
# 21317                                        0
# 36542                                        0
# 19134                                        0
# 6545                                         0
# ...                                        ...
# 3856                                         0
# 1696                                         0
# 2217                                         0
# 21486                                        0
# 14412                                        0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:8  \
# 8399                                         0
# 21317                                        0
# 36542                                        0
# 19134                                        0
# 6545                                         0
# ...                                        ...
# 3856                                         0
# 1696                                         0
# 2217                                         0
# 21486                                        0
# 14412                                        0
#
#        Tiempo_Duracion_Diligenciamiento_F3_9:9  Triaje_Re-clasificado_NO  \
# 8399                                         0                        50
# 21317                                        0                        50
# 36542                                        0                        50
# 19134                                        0                        50
# 6545                                         0                        50
# ...                                        ...                       ...
# 3856                                         0                        50
# 1696                                         0                         0
# 2217                                         0                        50
# 21486                                        0                        50
# 14412                                        0                        50
#
#        Triaje_Re-clasificado_SI  Clasificacion_1_Triaje_Enfermeria_
# 8399                          0                                 5.0
# 21317                         0                                 2.0
# 36542                         0                                 2.0
# 19134                         0                                 2.0
# 6545                          0                                 4.0
# ...                         ...                                 ...
# 3856                          0                                 3.0
# 1696                          7                                 3.0
# 2217                          0                                 3.0
# 21486                         0                                 2.0
# 14412                         0                                 2.0
#
# [9937 rows x 8628 columns]
